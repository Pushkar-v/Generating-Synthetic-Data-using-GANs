# %% [markdown]
# #### Timing TGAN module

# %% [markdown]
# # Result

# %% [markdown]
# ### Altering Columns
# | Data | # Rows  | # Continuous | # Categorical  | Time (Minutes) |
# |:---:|---:|---:|---:|---:|
# | Wisconsin | 569 | 30 | 0  | 50 |
# | Wisconsin | 569 | 14  | 0  | 30 |
# | Wisconsin | 569 | 7  | 0  | 11 |
# | Wisconsin | 569 | 2  |  0 | 6 |
# | Wisconsin | 1138 | 30  |  0 |  |
#
#
# ### Altering Rows
# | Data | # Rows  | # Continuous | # Categorical  | Time (Minutes) |
# |:---:|---:|---:|---:|---:|
# | Wisconsin | 1138 | 30 | 0  |  |
# | Wisconsin |  | 30  | 0  |  |
# | Wisconsin |  | 30 | 0  |  |
# | Wisconsin |  | 30 |  0 |  |
# | Wisconsin |  | 30 |  0 |  |

# %% [markdown]
# ## All Numeric Dataset

# %%
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings("ignore")


import time
import tensorflow as tf
import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False


import pandas as pd
import numpy as np
from tgan.model import TGANModel
# Out:
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\callbacks\hooks.py:17: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\optimizer.py:18: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\sesscreate.py:20: The name tf.train.SessionCreator is deprecated. Please use tf.compat.v1.train.SessionCreator instead.

# %%
data = pd.read_csv('D:\Scalability Check\ContinuousData.csv', sep = ',')
data.shape
# Out:
# (100000, 26)

# %%
data.head()
# Out:
#    SUBJECT_ID  NUMCALLOUT  NUMCPTEVENTS  NUMDIAGNOSIS  NUMOUTEVENTS  NUMRX  \
# 0          22           0             0             7             7      0
# 1          23           0             0             8            62     69
# 2          23           1             6            10            29     69
# 3          24           0             4             4             2     26
# 4          25           0             4             4            59     67
#
#    NUMPROCEVENTS  NUMMICROLABEVENTS  NUMPROC  NUMTRANSFERS  ...  \
# 0              0                  1        3             2  ...
# 1              0                  1        7             4  ...
# 2              4                  1        1             5  ...
# 3              0                  0        6             3  ...
# 4              0                  2        9             4  ...
#
#    NUMOUTEVENTS1  NUMRX1  NUMPROCEVENTS1  NUMMICROLABEVENTS1  NUMPROC1  \
# ...

# %% [markdown]
# ## Altering Number of Rows

# %% [markdown]
# ### Function

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data.iloc[1:1001,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:1001,:].shape)
# Out:
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\graph_builder\model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\graph_builder\model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\input_source\input_source.py:219: The name tf.FIFOQueue is deprecated. Please use tf.queue.FIFOQueue instead.
#
# [0419 12:32:23 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\summary.py:237: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data.iloc[1:10001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:10001:,:].shape)
# Out:
# [0419 13:28:16 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000212A6DF0308>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000212A6DF0308>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data.iloc[1:20001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:20001:,:].shape)
# Out:
# [0419 15:04:11 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000021330D80D08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000021330D80D08>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data.iloc[1:40001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:40001:,:].shape)
# Out:
# [0419 15:54:57 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000213562C4588>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000213562C4588>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data.iloc[1:60001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:60001:,:].shape)
# Out:
# [0419 18:32:09 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000213610F60C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000213610F60C8>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data.iloc[1:80001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:80001:,:].shape)
# Out:
# [0419 19:42:22 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000213BA4A3948>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000213BA4A3948>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = list(range(1,26)), restore_session=False)
tgan.fit(data)
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.shape)
# Out:
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\graph_builder\model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\graph_builder\model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\input_source\input_source.py:219: The name tf.FIFOQueue is deprecated. Please use tf.queue.FIFOQueue instead.
#
# [0420 00:53:00 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\summary.py:237: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# ...
