# %% [markdown]
# #### Timing TGAN module

# %% [markdown]
# # Result

# %% [markdown]
# ### Altering Columns
# | Data | # Rows  | # Continuous | # Categorical  | Time (Minutes) |
# |:---:|---:|---:|---:|---:|
# | Wisconsin | 569 | 30 | 0  | 50 |
# | Wisconsin | 569 | 14  | 0  | 30 |
# | Wisconsin | 569 | 7  | 0  | 11 |
# | Wisconsin | 569 | 2  |  0 | 6 |
# | Wisconsin | 1138 | 30  |  0 |  |
#
#
# ### Altering Rows
# | Data | # Rows  | # Continuous | # Categorical  | Time (Minutes) |
# |:---:|---:|---:|---:|---:|
# | Wisconsin | 1138 | 30 | 0  |  |
# | Wisconsin |  | 30  | 0  |  |
# | Wisconsin |  | 30 | 0  |  |
# | Wisconsin |  | 30 |  0 |  |
# | Wisconsin |  | 30 |  0 |  |

# %% [markdown]
# ## All Numeric Dataset

# %%
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings("ignore")


import time
import tensorflow as tf
import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False


import pandas as pd
import numpy as np
from tgan.model import TGANModel
# Out:
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\callbacks\hooks.py:17: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\optimizer.py:18: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\sesscreate.py:20: The name tf.train.SessionCreator is deprecated. Please use tf.compat.v1.train.SessionCreator instead.

# %%
data = pd.read_csv('D:\Data\Length of Stay\los_v1.csv', sep = ',')
data = data[~(data.loc[:,'LOS'].isnull())]
print(data.shape)
# Out:
# (116342, 27)

# %%
data.head()
# Out:
#        final_id ADMISSION_TYPE   INSURANCE               ETHNICITY  \
# 0     10_184167        NEWBORN    Medicaid  BLACK/AFRICAN AMERICAN
# 1    100_153952       ELECTIVE     Private   UNKNOWN/NOT SPECIFIED
# 2   1000_143040         URGENT     Private   UNKNOWN/NOT SPECIFIED
# 3  10000_187813      EMERGENCY    Self Pay      HISPANIC OR LATINO
# 4  10001_118420        NEWBORN  Government                   ASIAN
#
#    HOSPITAL_EXPIRE_FLAG GENDER  EXPIRE_FLAG      LOS  \
# 0                     0      F            0   8.0921
# 1                     0      F            0   2.1167
# 2                     1      M            1  36.7002
# 3                     0      M            0   1.3263
# 4                     0      M            0   0.1021
#
#    certain conditions originating in the perinatal period  \
# 0                                                  3
# 1                                                  0
# 2                                                  0
# ...

# %%
data = data.iloc[:,[2,3,4,5,6,8,9,10,11,12]]
data.head()
# Out:
#     INSURANCE               ETHNICITY  HOSPITAL_EXPIRE_FLAG GENDER  \
# 0    Medicaid  BLACK/AFRICAN AMERICAN                     0      F
# 1     Private   UNKNOWN/NOT SPECIFIED                     0      F
# 2     Private   UNKNOWN/NOT SPECIFIED                     1      M
# 3    Self Pay      HISPANIC OR LATINO                     0      M
# 4  Government                   ASIAN                     0      M
#
#    EXPIRE_FLAG  certain conditions originating in the perinatal period  \
# 0            0                                                  3
# 1            0                                                  0
# 2            1                                                  0
# 3            0                                                  0
# 4            0                                                  0
#
#    complications of pregnancy, childbirth, and the puerperium  \
# 0                                                  0
# ...

# %% [markdown]
# ## Altering Number of Rows

# %% [markdown]
# ### Function

# %%
def timing(data, lst):
    # tf.reset_default_graph()
    a1 = time.time()
    tgan = TGANModel(continuous_columns = lst, restore_session=False)
    tgan.fit(data)
    b1 = time.time()
    print('time : ', b1-a1)
    print("Number of cols : ", data.shape[1])

# %%
#timing(data, [7])
# Out:
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\graph_builder\model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\graph_builder\model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\input_source\input_source.py:219: The name tf.FIFOQueue is deprecated. Please use tf.queue.FIFOQueue instead.
#
# [0415 12:53:51 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From D:\Python\lib\site-packages\tensorpack\tfutils\summary.py:237: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = [], restore_session=False)
tgan.fit(data.iloc[1:1000:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:1000:,:].shape)
# Out:
# [0416 02:17:02 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000027910DF4248>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000027910DF4248>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = [], restore_session=False)
tgan.fit(data.iloc[1:5001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:5001:,:].shape)
# Out:
# [0416 02:34:20 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002791E404C08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002791E404C08>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = [], restore_session=False)
tgan.fit(data.iloc[1:10001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:10001:,:].shape)
# Out:
# [0416 02:52:13 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000027948BB8548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x0000027948BB8548>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = [], restore_session=False)
tgan.fit(data.iloc[1:20001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:20001:,:].shape)
# Out:
# [0416 03:52:38 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002794FAC2248>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002794FAC2248>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = [], restore_session=False)
tgan.fit(data.iloc[1:40001:,:])
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.iloc[1:40001:,:].shape)
# Out:
# [0416 04:03:54 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002798E527548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000002798E527548>>: AttributeError: module 'gast' has no attribute 'Num'
# ...

# %%
tf.reset_default_graph()
a1 = time.time()
tgan = TGANModel(continuous_columns = [], restore_session=False)
tgan.fit(data)
b1 = time.time()
print('time : ', b1-a1)
print("Number of Rows : ", data.shape)
# Out:
# [0416 04:20:50 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000279949A7648>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x00000279949A7648>>: AttributeError: module 'gast' has no attribute 'Num'
# ...
