# %% [markdown]
# # Timing TGAN module

# %% [markdown]
# # Result

# %% [markdown]
# ### Altering Columns
# | Data | # Rows  | # Continuous | # Categorical  | Time (Minutes) |
# |:---:|---:|---:|---:|---:|
# | Wisconsin | 569 | 30 | 0  | 50 |
# | Wisconsin | 569 | 14  | 0  | 30 |
# | Wisconsin | 569 | 7  | 0  | 11 |
# | Wisconsin | 569 | 2  |  0 | 6 |
# | Wisconsin | 1138 | 30  |  0 |  |
#
#
# ### Altering Rows
# | Data | # Rows  | # Continuous | # Categorical  | Time (Minutes) |
# |:---:|---:|---:|---:|---:|
# | Wisconsin | 1138 | 30 | 0  |  |
# | Wisconsin |  | 30  | 0  |  |
# | Wisconsin |  | 30 | 0  |  |
# | Wisconsin |  | 30 |  0 |  |
# | Wisconsin |  | 30 |  0 |  |

# %% [markdown]
# ## All Numeric Dataset

# %%
import pandas as pd
import numpy as numpy
import time

from ctgan import CTGANSynthesizer

# %%
data = pd.read_csv('D:\Data\Length of Stay\los_v1.csv', sep = ',')
data = data[~(data.loc[:,'LOS'].isnull())]
print(data.shape)
# Out:
# (116342, 27)

# %%
data.head()
# Out:
#        final_id ADMISSION_TYPE   INSURANCE               ETHNICITY  \
# 0     10_184167        NEWBORN    Medicaid  BLACK/AFRICAN AMERICAN
# 1    100_153952       ELECTIVE     Private   UNKNOWN/NOT SPECIFIED
# 2   1000_143040         URGENT     Private   UNKNOWN/NOT SPECIFIED
# 3  10000_187813      EMERGENCY    Self Pay      HISPANIC OR LATINO
# 4  10001_118420        NEWBORN  Government                   ASIAN
#
#    HOSPITAL_EXPIRE_FLAG GENDER  EXPIRE_FLAG      LOS  \
# 0                     0      F            0   8.0921
# 1                     0      F            0   2.1167
# 2                     1      M            1  36.7002
# 3                     0      M            0   1.3263
# 4                     0      M            0   0.1021
#
#    certain conditions originating in the perinatal period  \
# 0                                                  3
# 1                                                  0
# 2                                                  0
# ...

# %% [markdown]
# ## Altering Number of Rows

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:1000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:1000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:10000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:10000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:20000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:20000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:30000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:40000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:40000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:40000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:50000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:50000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:100000,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:100000,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...

# %%
discrete_columns = data.columns
a = time.time()
ctgan = CTGANSynthesizer()
ctgan.fit(data.iloc[:,1:], discrete_columns, epochs = 5)
b = time.time()

print(b-a)
print('data shape:', data.iloc[:,1:].shape)
# Out:
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# D:\Python\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# ...
